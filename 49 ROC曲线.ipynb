# %%
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt

digits = datasets.load_digits()
X = digits.data
y = digits.target.copy()

y[digits.target==9] = 1
y[digits.target!=9] = 0

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=6670)

from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
decision_scores = log_reg.decision_function(X_test)

import sys#引用不在一个文件夹中的.py文件
sys.path.append(r'.\Pycharm\LogisticRegression')
from metrics import FPR,TPR

thresholds = np.arange(np.min(decision_scores),np.max(decision_scores),0.1)
fprs = []
tprs = []
for threshold in thresholds:
    y_predict = np.array(decision_scores >= threshold, dtype='int')
    fprs.append(FPR(y_test, y_predict))
    tprs.append(TPR(y_test, y_predict))
    
plt.plot(thresholds,fprs,color='g',label='FPR')
plt.plot(thresholds,tprs,color='r',label='TPR')
plt.legend()
plt.show()

plt.plot(fprs, tprs)
plt.show()

from sklearn.metrics import roc_auc_score
score = roc_auc_score(y_test, decision_scores)
print(score)
# Out:
# 0.9924429019256606

# %%
#kNN
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt

digits = datasets.load_digits()
X = digits.data
y = digits.target.copy()

y[digits.target==9] = 1
y[digits.target!=9] = 0

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=6670)

from sklearn.neighbors import KNeighborsClassifier
knn_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
decision_scores = log_reg.decision_function(X_test)

import sys#引用不在一个文件夹中的.py文件
sys.path.append(r'.\Pycharm\LogisticRegression')
from metrics import FPR,TPR

thresholds = np.arange(np.min(decision_scores),np.max(decision_scores),0.1)
fprs = []
tprs = []
for threshold in thresholds:
    y_predict = np.array(decision_scores >= threshold, dtype='int')
    fprs.append(FPR(y_test, y_predict))
    tprs.append(TPR(y_test, y_predict))
    
plt.plot(thresholds,fprs,color='g',label='FPR')
plt.plot(thresholds,tprs,color='r',label='TPR')
plt.legend()
plt.show()

plt.plot(fprs, tprs)
plt.show()

from sklearn.metrics import roc_auc_score
score = roc_auc_score(y_test, decision_scores)
print(score)

# %%
from sklearn.metrics import roc_curve
fprs, tprs, thresholds = roc_curve(y_test, decision_scores)

plt.plot(thresholds,fprs,color='g',label='FPR')
plt.plot(thresholds,tprs,color='r',label='TPR')
plt.legend()
plt.show()

plt.plot(fprs, tprs)
plt.show()

from sklearn.metrics import roc_auc_score
score = roc_auc_score(y_test, decision_scores)
print(score)
# Out:
# 0.9924429019256606
